# %% [markdown]
# # 3) 문서 단어 행렬(Document-Term Matrix, DTM)

# %% [markdown]
# ### 1. 문서 단어 행렬(Document-Term Matrix, DTM)의 표기법

# %% [markdown]
# * 문서 단어 행렬 : 다수의 문서에서 등장하는 단어들의 빈도수를 행렬로 표기한 것.

# %% [markdown]
# * 문서1 : 먹고 싶은 사과
# * 문서2 : 먹고 싶은 바나나
# * 문서3 : 길고 노란 바나나 바나나
# * 문서4 : 저는 과일이 좋아요

# %% [markdown]
# <DTM으로 표현>\
# ![image.png](attachment:695c5697-f4ed-4443-aa7d-96c0e5b6df12.png)

# %% [markdown]
# ### 2. 문서 단어 행렬(Document-Term Matrix)의 한계

# %% [markdown]
# * Spares representation(희소 표현)
# * 단순 빈도 수 기반 접근
